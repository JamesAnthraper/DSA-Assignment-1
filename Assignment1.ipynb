# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel(r"D:\James\DSA\Assignments\iris.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(data.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])

# %%
plt.bar("Classification","SL",data=data)
plt.ylabel("SL")
plt.xlabel("Classification")
# Out:
# Text(0.5, 0, 'Classification')

# %%
plt.bar("Classification","SW",data=data)
plt.ylabel("SW")
plt.xlabel("Classification")
# Out:
# Text(0.5, 0, 'Classification')

# %%
plt.bar("Classification","PL",data=data)
plt.ylabel("PL")
plt.xlabel("Classification")
# Out:
# Text(0.5, 0, 'Classification')

# %%
plt.bar("Classification","PW",data=data)
plt.ylabel("PW")
plt.xlabel("Classification")
# Out:
# Text(0.5, 0, 'Classification')

# %%
sns.boxplot(x=data['Classification'], y=data['SL'] )
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.boxplot(x=data['Classification'], y=data['SW'] )
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %%
sns.boxplot(x=data['Classification'], y=data['PL'] )
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.boxplot(x=data['Classification'], y=data['PW'] )
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>
